# %%
import asyncio
from agent_framework import ChatAgent
from agent_framework.azure import AzureAIAgentClient
from azure.identity.aio import AzureCliCredential
import os
import dotenv
dotenv.load_dotenv()

Azure_AI_Foundry_project_endpoint = os.getenv("Azure_AI_Foundry_project_endpoint")
Azure_AI_Model_Deployment = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")


async def main():
    async with AzureCliCredential() as credential:
        async with ChatAgent(
            chat_client=AzureAIAgentClient(
                async_credential=credential,
                project_endpoint=Azure_AI_Foundry_project_endpoint,
                model_deployment_name=Azure_AI_Model_Deployment
            ),
            instructions="You are a dental insurance agent and analyst"
        ) as agent:
            result = await agent.run("How are dental insurance carriers doing in 2025?")
            print(result.text)

await main()
# Out:
# As of 2025, dental insurance carriers are experiencing a dynamic landscape influenced by several key trends and factors:
#
# 1. **Market Growth and Enrollment:**
#    - Dental insurance continues to see steady growth, supported by increased consumer awareness of oral health's connection to overall wellness.
#    - Employers are increasingly offering dental benefits to attract and retain employees, contributing to higher group plan enrollments.
#    - Individual dental plans are also gaining traction, especially through Health Insurance Marketplaces and direct-to-consumer platforms.
#
# 2. **Technology and Digital Transformation:**
#    - Carriers are investing heavily in digital tools like AI-driven claims processing, tele-dentistry services, and mobile apps for member engagement.
#    - These innovations improve customer experience, reduce administrative costs, and streamline provider networks.
#
# 3. **Benefit Design Evolution:**
#    - There is a trend toward more flexible and tiered plan designs, including enhanced preventive care and better coverage for cosmetic and specialized procedures.
#    - Some carriers are integrating dental benefits with medical plans to address systemic health issues linked to oral health.
#
# 4. **Regulatory Environment:**
#    - Regulatory scrutiny remains focused on transparency, network adequacy, and claim denials.
#    - Carriers are adapting to evolving federal and state mandates, including those related to data privacy and patient rights.
#
# 5. **Financial Performance:**
#    - Many carriers report stable or improved profitability, driven by effective cost management and pricing strategies.
#    - However, rising dental care costs and increased usage pose challenges that require careful balancing of premiums and benefits.
#
# 6. **Competitive Landscape:**
#    - The market sees consolidation with mergers and acquisitions among carriers aiming to scale and diversify offerings.
#    - New entrants, including tech-focused startups and non-traditional insurers, are intensifying competition.
#
# **Summary:**
# Dental insurance carriers in 2025 are generally doing well, adapting to market demands and technological advances, while navigating regulatory and cost pressures. Their success hinges on innovation, consumer-centric products, and strategic partnerships. If you want, I can provide insights into specific carriers, market forecasts, or emerging opportunities in dental insurance this year.
