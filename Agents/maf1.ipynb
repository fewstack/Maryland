# %%
import os
import agent_framework

import dotenv
dotenv.load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 import agent_framework
#       4 import dotenv
#       5 dotenv.load_dotenv()
#
# File c:\2026\Maryland\.venv\Lib\site-packages\agent_framework\__init__.py:13
#      10     _version = "0.0.0"  # Fallback for development mode
#      11 __version__: Final[str] = _version
# ---> 13 from ._agents import *  # noqa: F403
#      14 from ._clients import *  # noqa: F403
#      15 from ._logging import *  # noqa: F403
#
# File c:\2026\Maryland\.venv\Lib\site-packages\agent_framework\_agents.py:14
#      10 from uuid import uuid4
#      12 from pydantic import BaseModel, Field, create_model
# ---> 14 from ._clients import BaseChatClient, ChatClientProtocol
#      15 from ._logging import get_logger
#      16 from ._mcp import MCPTool
#
# ...
